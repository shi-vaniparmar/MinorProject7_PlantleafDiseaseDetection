# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 16
IMAGE_SIZE = 256
# Images are RGB
CHANNELS=3
EPOCHS=25

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/kaggle/input/citrus-leaf-disease-image/Citrus Leaf Disease Image",
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 607 files belonging to 5 classes.

# %%
class_names=dataset.class_names
class_names
# Out:
# ['Black spot', 'Canker', 'Greening', 'Healthy', 'Melanose']

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (16, 256, 256, 3)
# [2 1 2 1 1 0 2 0 3 3 2 2 2 1 1 3]

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(6):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
len(dataset)
# Out:
# 38

# %%
# 80% = training
# 10% validation
# 10% test
train_size = 0.8
len(dataset)*train_size
# Out:
# 30.400000000000002

# %%
15*40
# Out:
# 600

# %%
train_ds = dataset.take(30)
len(train_ds)
# Out:
# 30

# %%
test_ds = dataset.skip(30)
len(test_ds)
# Out:
# 8

# %%
val_size=0.1
len(dataset)*val_size
# Out:
# 3.8000000000000003

# %%
val_ds = test_ds.take(3)
len(val_ds)
# Out:
# 3

# %%
test_ds = test_ds.skip(3)
len(test_ds)
# Out:
# 5

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 30

# %%
len(val_ds)
# Out:
# 3

# %%
len(test_ds)
# Out:
# 5

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 5



# Create the model
model = models.Sequential([
    resize_and_rescale,
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
    layers.BatchNormalization(),  # Add Batch Normalization
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.BatchNormalization(),  # Add Batch Normalization
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.BatchNormalization(),  # Add Batch Normalization
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),  # Add Batch Normalization
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),  # Add Batch Normalization
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),  # Add Batch Normalization
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),  # Add Dropout
    layers.Dense(n_classes, activation='softmax'),
])

model.build(input_shape=input_shape)

# import keras
# from keras.models import Sequential
# from keras.layers import Conv2D, Activation, MaxPooling2D, Flatten, Dense
# import keras.backend as K

# model = Sequential()
# n_classes = 5
# inputShape = (256, 256, 3)  # Update with your actual input shape
# chanDim = -1

# if K.image_data_format() == "channels_first":
#     inputShape = (3, 256, 256)  # Update with your actual input shape
#     chanDim = 1
# Model.add(Conv2D(32,(3,3),inputshape=,activation=‘relu′))
# Model.add(MaxPooling2D(pool_size=(2,2)))
# Model1.add(conv2D(32,(3,3),activation=‘relu′))
# Model.add(MaxPooling2D(poolsize=(2,2)))
# Model.add(Flattn())
# Model.add(Dense(units=128,activation=′softmax))

# model.add(Conv2D(32, (3, 3), padding="same",input_shape=inputShape))
# model.add(Activation("relu"))
# model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Conv2D(32, (3, 3), padding="same"))
# model.add(Activation("relu"))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Flatten())
# model.add(Dense(128))
# model.add(Dense(n_classes))
# model.add(Activation("softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (16, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (16, 254, 254, 32)        896
#
#  batch_normalization (BatchN  (16, 254, 254, 32)       128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (16, 127, 127, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (16, 125, 125, 64)        18496
#
#  batch_normalization_1 (Batc  (16, 125, 125, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (16, 62, 62, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (16, 60, 60, 64)          36928
#
#  batch_normalization_2 (Batc  (16, 60, 60, 64)         256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (16, 30, 30, 64)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (16, 28, 28, 64)          36928
#
#  batch_normalization_3 (Batc  (16, 28, 28, 64)         256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (16, 14, 14, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (16, 12, 12, 64)          36928
#
#  batch_normalization_4 (Batc  (16, 12, 12, 64)         256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (16, 6, 6, 64)           0
#  2D)
#
#  conv2d_5 (Conv2D)           (16, 4, 4, 64)            36928
#
#  batch_normalization_5 (Batc  (16, 4, 4, 64)           256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (16, 2, 2, 64)           0
#  2D)
#
#  flatten (Flatten)           (16, 256)                 0
#
#  dense (Dense)               (16, 64)                  16448
#
#  dropout (Dropout)           (16, 64)                  0
#
#  dense_1 (Dense)             (16, 5)                   325
#
# =================================================================
# Total params: 185,285
# Trainable params: 184,581
# Non-trainable params: 704
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=25,
)
# Out:
# Epoch 1/25
# 30/30 [==============================] - 61s 2s/step - loss: 1.6366 - accuracy: 0.4384 - val_loss: 1.6834 - val_accuracy: 0.1042
# Epoch 2/25
# 30/30 [==============================] - 54s 2s/step - loss: 1.0015 - accuracy: 0.6493 - val_loss: 1.7319 - val_accuracy: 0.3542
# Epoch 3/25
# 30/30 [==============================] - 53s 2s/step - loss: 0.6833 - accuracy: 0.7244 - val_loss: 2.1094 - val_accuracy: 0.3542
# Epoch 4/25
# 30/30 [==============================] - 54s 2s/step - loss: 0.5748 - accuracy: 0.7641 - val_loss: 2.6851 - val_accuracy: 0.3542
# Epoch 5/25
# 30/30 [==============================] - 54s 2s/step - loss: 0.5228 - accuracy: 0.7808 - val_loss: 3.1091 - val_accuracy: 0.3542
# Epoch 6/25
# 30/30 [==============================] - 53s 2s/step - loss: 0.4742 - accuracy: 0.8267 - val_loss: 2.9094 - val_accuracy: 0.3750
# Epoch 7/25
# 30/30 [==============================] - 54s 2s/step - loss: 0.3854 - accuracy: 0.8580 - val_loss: 3.5735 - val_accuracy: 0.3542
# Epoch 8/25
# 30/30 [==============================] - 54s 2s/step - loss: 0.3803 - accuracy: 0.8518 - val_loss: 3.7196 - val_accuracy: 0.3542
# Epoch 9/25
# 30/30 [==============================] - 54s 2s/step - loss: 0.3914 - accuracy: 0.8476 - val_loss: 2.9281 - val_accuracy: 0.3542
# Epoch 10/25
# 30/30 [==============================] - 54s 2s/step - loss: 0.3128 - accuracy: 0.8935 - val_loss: 3.5036 - val_accuracy: 0.3542
# Epoch 11/25
# 30/30 [==============================] - 53s 2s/step - loss: 0.2640 - accuracy: 0.9061 - val_loss: 3.2849 - val_accuracy: 0.3958
# Epoch 12/25
# 30/30 [==============================] - 53s 2s/step - loss: 0.3579 - accuracy: 0.8747 - val_loss: 4.0798 - val_accuracy: 0.4167
# Epoch 13/25
# 30/30 [==============================] - 54s 2s/step - loss: 0.3272 - accuracy: 0.8706 - val_loss: 1.7325 - val_accuracy: 0.4583
# Epoch 14/25
# 30/30 [==============================] - 53s 2s/step - loss: 0.2621 - accuracy: 0.9061 - val_loss: 2.5726 - val_accuracy: 0.3125
# Epoch 15/25
# 30/30 [==============================] - 53s 2s/step - loss: 0.2377 - accuracy: 0.9165 - val_loss: 1.0603 - val_accuracy: 0.5833
# Epoch 16/25
# 30/30 [==============================] - 54s 2s/step - loss: 0.2953 - accuracy: 0.8873 - val_loss: 1.8735 - val_accuracy: 0.4583
# Epoch 17/25
# 30/30 [==============================] - 53s 2s/step - loss: 0.2344 - accuracy: 0.9040 - val_loss: 1.4728 - val_accuracy: 0.5833
# Epoch 18/25
# 30/30 [==============================] - 53s 2s/step - loss: 0.2250 - accuracy: 0.9081 - val_loss: 2.2255 - val_accuracy: 0.5000
# Epoch 19/25
# 30/30 [==============================] - 53s 2s/step - loss: 0.2796 - accuracy: 0.8998 - val_loss: 0.9923 - val_accuracy: 0.6458
# Epoch 20/25
# 30/30 [==============================] - 53s 2s/step - loss: 0.2293 - accuracy: 0.9290 - val_loss: 0.5537 - val_accuracy: 0.8333
# Epoch 21/25
# 30/30 [==============================] - 54s 2s/step - loss: 0.2126 - accuracy: 0.9269 - val_loss: 0.5636 - val_accuracy: 0.7500
# Epoch 22/25
# 30/30 [==============================] - 54s 2s/step - loss: 0.2057 - accuracy: 0.9165 - val_loss: 0.9710 - val_accuracy: 0.7083
# Epoch 23/25
# 30/30 [==============================] - 53s 2s/step - loss: 0.1875 - accuracy: 0.9228 - val_loss: 1.7479 - val_accuracy: 0.6458
# Epoch 24/25
# 30/30 [==============================] - 54s 2s/step - loss: 0.2116 - accuracy: 0.9207 - val_loss: 1.4373 - val_accuracy: 0.6458
# Epoch 25/25
# 30/30 [==============================] - 54s 2s/step - loss: 0.1797 - accuracy: 0.9248 - val_loss: 0.3002 - val_accuracy: 0.8542

# %%
scores = model.evaluate(test_ds)
# Out:
# 5/5 [==============================] - 3s 456ms/step - loss: 0.3225 - accuracy: 0.8875

# %%
scores
# Out:
# [0.322491317987442, 0.887499988079071]

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 25, 'steps': 30}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
type(history.history['loss'])
# Out:
# list

# %%
len(history.history['loss'])
# Out:
# 25

# %%
history.history['loss'][:5] # show loss for first 5 epochs
# Out:
# [1.6365699768066406,
#  1.0015040636062622,
#  0.6832950115203857,
#  0.5747547745704651,
#  0.5227536559104919]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Canker
# 1/1 [==============================] - 1s 654ms/step
# predicted label: Canker

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step

# %%
# import os
# model_version=max([int(i) for i in os.listdir("/kaggle/working/") + [0]])+1
# model.save(f"/kaggle/working/{model_version}")

# %%
# model.save("../citrus.h5")
